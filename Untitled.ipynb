# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fp_b = r"data\04_oct_cleaned_pickled_batter_data.pkl"
fp_p = r"data\04_oct_cleaned_pickled_pitcher_data.pkl"

# %%
b_raw = pd.read_pickle(fp_b)

# %%
dims = ["player_name", "year", "team"]
xdims = ["age", "position"]
sal = ["salary", "log_salary", "next_year_salary", "next_year_log_salary", "league_min", "salary_over_minimum", "player_at_min"]
stats = ["avg", "hr", "obp", "ops", "pa", "rbi", "slg", "war"]

# %%
batters = (b_raw
           .sort_values(dims)
           .assign(one=1)
           .pipe(lambda df: df.assign(year_num=df.groupby(["player_name"]).one.cumsum()))
           .pipe(lambda df: df.assign(position=df.position.apply(lambda s: s.replace(",", " ").split(" ")[0])))
          )

# %%
batters.head()
# Out:
#       age    avg    hr    obp    ops     pa player_name position   rbi  \
# 2100   31  0.270  13.0  0.373  0.786  505.0  A.J. Ellis  Catcher  52.0
# 2105   32  0.238  10.0  0.318  0.682  448.0  A.J. Ellis  Catcher  52.0
# 2113   33  0.191   3.0  0.323  0.577  347.0  A.J. Ellis  Catcher  25.0
# 2117   34  0.238   7.0  0.355  0.758  217.0  A.J. Ellis  Catcher  21.0
# 2123   36  0.201   6.0  0.288  0.655  158.0  A.J. Ellis  Catcher  14.0
#
#          salary  ...  war  year  log_salary  next_year_salary  \
# 2100   490000.0  ...  3.4  2012   13.102161          421000.0
# 2105  2000000.0  ...  2.3  2013   14.508658          490000.0
# 2113  3550000.0  ...  0.0  2014   15.082458         2000000.0
# 2117  4250000.0  ...  1.6  2015   15.262430         3550000.0
# 2123  2500000.0  ...  0.4  2017   14.731801         4500000.0
#
#       next_year_log_salary  league_min  salary_over_minimum  player_at_min  \
# 2100             12.950388    480000.0             -59000.0            1.0
# 2105             13.102161    507500.0             -17500.0            1.0
# 2113             14.508658    507500.0            1492500.0            0.0
# 2117             15.082458    535000.0            3015000.0            0.0
# 2123             15.319588    555000.0            3945000.0            0.0
#
#       one  year_num
# 2100    1         1
# 2105    1         2
# 2113    1         3
# 2117    1         4
# 2123    1         5
#
# [5 rows x 22 columns]

# %%
X_cols = ["year_num", "war"]
y_cols = ['next_year_log_salary']

batters = batters[batters.pa > 100]
batters = batters.sort_values(X_cols[0])
X = batters[X_cols]
X = pd.get_dummies(X)
y = batters[y_cols]
X = sm.add_constant(X, prepend=False)

mod = sm.OLS(y, X)
res = mod.fit()
# Out:
# C:\Users\David\Anaconda3\envs\jupyter_lab\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return getattr(obj, method)(*args, **kwds)

# %%
print(res.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     next_year_log_salary   R-squared:                       0.424
# Model:                              OLS   Adj. R-squared:                  0.424
# Method:                   Least Squares   F-statistic:                     1630.
# Date:                  Sun, 05 Apr 2020   Prob (F-statistic):               0.00
# Time:                          13:14:21   Log-Likelihood:                -6391.0
# No. Observations:                  4432   AIC:                         1.279e+04
# Df Residuals:                      4429   BIC:                         1.281e+04
# Df Model:                             2
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# year_num       0.3343      0.006     55.746      0.000       0.323       0.346
# war            0.1273      0.008     15.978      0.000       0.112       0.143
# const         12.8635      0.030    423.998      0.000      12.804      12.923
# ==============================================================================
# Omnibus:                      657.735   Durbin-Watson:                   1.834
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8992.706
# Skew:                          -0.210   Prob(JB):                         0.00
# Kurtosis:                       9.966   Cond. No.                         9.65
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
resid = y.values - res.fittedvalues.values.reshape(-1, 1)
plt.figure(figsize=(12, 4))
plt.scatter(range(0, len(resid)), resid, alpha=0.2)
plt.plot(range(0, len(resid)), np.zeros(len(resid)), 'r--');
